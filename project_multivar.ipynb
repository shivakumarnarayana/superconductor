# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("train.csv")

# %%
data
# Out:
#        number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                       4         88.944468             57.862692
# 1                       5         92.729214             58.518416
# 2                       4         88.944468             57.885242
# 3                       4         88.944468             57.873967
# 4                       4         88.944468             57.840143
# 5                       4         88.944468             57.795044
# 6                       4         88.944468             57.682296
# 7                       4         76.517718             57.175142
# 8                       4         76.517718             56.808817
# 9                       4         76.517718             56.442492
# 10                      4         76.517718             55.709843
# 11                      5        111.273574             63.713457
# 12                      5         92.729214             58.201829
# ...

# %%
dd=data.corr()
dd
# Out:
#                                  number_of_elements  mean_atomic_mass  \
# number_of_elements                         1.000000         -0.141923
# mean_atomic_mass                          -0.141923          1.000000
# wtd_mean_atomic_mass                      -0.353064          0.815977
# gmean_atomic_mass                         -0.292969          0.940298
# wtd_gmean_atomic_mass                     -0.454525          0.745841
# entropy_atomic_mass                        0.939304         -0.104000
# wtd_entropy_atomic_mass                    0.881845         -0.097609
# range_atomic_mass                          0.682777          0.125659
# wtd_range_atomic_mass                     -0.320293          0.446225
# std_atomic_mass                            0.513998          0.196460
# wtd_std_atomic_mass                        0.546391          0.130675
# mean_fie                                   0.167451         -0.285782
# ...

# %%
print(abs(dd['critical_temp']).sort_values())
# Out:
# gmean_fie                          0.025103
# entropy_ThermalConductivity        0.085862
# mean_fie                           0.102268
# mean_atomic_radius                 0.105273
# wtd_gmean_ElectronAffinity         0.107359
# wtd_mean_ElectronAffinity          0.111516
# mean_atomic_mass                   0.113523
# std_Density                        0.115243
# wtd_entropy_ThermalConductivity    0.116728
# range_FusionHeat                   0.140714
# range_Valence                      0.143546
# gmean_atomic_radius                0.143770
# wtd_range_ElectronAffinity         0.185348
# mean_ElectronAffinity              0.193550
# wtd_std_FusionHeat                 0.195571
# std_FusionHeat                     0.201310
# wtd_std_Density                    0.207663
# std_Valence                        0.208072
# gmean_atomic_mass                  0.230345
# wtd_entropy_ElectronAffinity       0.237648
# range_Density                      0.260536
# ...

# %%
x=data["range_ThermalConductivity"]
y=data["critical_temp"]
z=data["wtd_std_ThermalConductivity"]

# %%
plt.plot(x,z,"b.")

# %%
x1=np.array((x-x.min())/(x.max()-x.min()))

# %%
x2=np.array((z-z.min())/(z.max()-z.min()))

# %%
x=np.array((x-x.min())/(x.max()-x.min()))
y=np.array((y-y.min())/(y.max()-y.min()))

# %%
plt.plot(x1,y,"r.",x2,y,"b.")

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
def hypothesis(a,b,x):
    return np.exp(a*x+b)

# %%
def error(a,b,x,y):
    err=0
    m=len(x)
    
    for i in range(m):
        err+=np.power(hypothesis(a,b,x[i])-y[i],2)
        
    return (1/(2*m))*err

# %%
def step_gradient(a,b,x,y,learning_rate):
    grad_a=0
    grad_b=0
    m=len(x)
    
    for i in range(m):
        grad_a+=(1/m)*(hypothesis(a,b,x[i])-y[i])*np.exp(a*x[i]+b)*x[i]
        grad_b+=(1/m)*(hypothesis(a,b,x[i])-y[i])*np.exp(a*x[i]+b)
        
    a=a-grad_a*learning_rate
    b=b-grad_b*learning_rate
    
    return a,b

# %%
def descend(init_a,init_b,x,y,learning_rate,iterations):
    a=init_a
    b=init_b 
    
    for i in range(iterations):
        e=error(a,b,x,y)
    
        if i%1000 == 0:
            print(f"Error:{np.sqrt(e)},a:{a},b:{b}")
    
        a,b=step_gradient(a,b,x,y,learning_rate)
    
    return a,b

# %%
a =0.01380395323236466
b = 0.009557423332633291
c = 0.01483934440894804
learning_rate = 0.1
iterations = 10000

# %%
final_a,final_b=descend(a,b,x_train,y_train,learning_rate,iterations)
# Out:
# Error:0.6020496412004454,a:0.01380395323236466,b:0.009557423332633291
# Error:0.12340140433618016,a:0.2482951454470404,b:-1.7069658807928731
# Error:0.10981038911521118,a:0.7274899348148707,b:-1.9910084369290801
# Error:0.10368364134068686,a:1.01681498212904,b:-2.204287883054193
# Error:0.10046939962654207,a:1.2164877259807223,b:-2.363232089288914
# Error:0.09856306859976628,a:1.366246125267129,b:-2.487043573913941
# Error:0.09733064052816935,a:1.4846908724175314,b:-2.587194685329045
# Error:0.09648294263405648,a:1.5818336752558821,b:-2.6705662296910444
# Error:0.09587230090598871,a:1.6636252106811749,b:-2.7415094064060925
# Error:0.09541648367347406,a:1.7338692740538164,b:-2.8029201475040932

# %%
plt.plot(x_train,y_train,"r.",
         x_train,hypothesis(a,b,x_train),"g.",
         x_train,hypothesis(final_a,final_b,x_train),"b.")
